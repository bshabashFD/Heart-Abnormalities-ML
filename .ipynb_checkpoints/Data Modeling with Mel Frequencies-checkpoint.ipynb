# %%
import numpy as np
import pandas as pd
import time
import librosa
import librosa.display

import warnings
warnings.filterwarnings("ignore")

import matplotlib.pyplot as plt
# %matplotlib inline

from boris_util import *

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier


from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# # Exploring the Dataset
#
# First thing's first, let's load the dataset. I created a new function that loads up the dataset for me and converts it into a pandas dataframe for easy access. For more information on this, please see the `Data Cleaning` notebook

# %%
dataset = read_and_combine_data('453_923_bundle_archive', read_noisy_data=False)
print()
print(dataset.shape)
dataset.head()
# Out:
# processed 100.00%
#
# (436, 3)
#                                               signal  sampling_rate     label
# 0  [2.2960085e-05, -0.00012982322, -0.00018070513...          22050  artifact
# 1  [-1.0927635e-05, 1.0574424e-06, 2.108567e-06, ...          22050  artifact
# 2  [3.728857e-05, -0.0001664555, -7.4023155e-05, ...          22050  artifact
# 3  [-0.0027429417, -0.0066496185, -0.0049779303, ...          22050  artifact
# 4  [0.000106223946, 0.0015002153, 0.0097254915, 0...          22050  artifact

# %% [markdown]
# Let's take a look at the class distribution to see if there is any concern of class imbalance

# %%
label_counts = dataset['label'].value_counts()

plt.figure(figsize=(15,5))
plt.barh(label_counts.index, label_counts.values)
plt.xlabel("Value Counts")
plt.ylabel("Condition")
plt.title("The Distribution of Different Labels in the Dataset")
plt.show()

# %% [markdown]
# There is certainly an issue of class imbalance here. A naive classifier could guess pretty well by simply guessing "Normal" on all the examples

# %% [markdown]
# ## Combine all Abnormalities
#
# Let's try a simple example first, we will combine all abnormalities into a single label "abnormal". We won't count artifacts in that category

# %%
def relabel(label):
    if (label == "normal"):
        return "normal"
    else:
        return "abnormal"
dataset['label'] = dataset['label'].apply(relabel)

# %%
label_counts = dataset['label'].value_counts()

plt.figure(figsize=(15,5))
plt.barh(label_counts.index, label_counts.values)
plt.xlabel("Value Counts")
plt.ylabel("Condition")
plt.title("The Distribution of Different Labels in the Re-labeled Dataset")
plt.show()

# %% [markdown]
# Let's split our data now into a simple train/test stratified split

# %%
from sklearn.model_selection import train_test_split

train_dataset, test_dataset = train_test_split(dataset, test_size=0.3, stratify=dataset['label'], random_state=1)
print(train_dataset.shape)
print(test_dataset.shape)
# Out:
# (305, 3)
# (131, 3)

# %%
train_dataset.head()
# Out:
#                                                 signal  sampling_rate   label
# 302  [-0.014594975, -0.016623363, -0.017930867, -0....          22050  normal
# 401  [0.00535502, 0.0048318487, 0.0038144102, 0.002...          22050  normal
# 311  [-0.0009814408, -0.00052338943, 9.0988244e-05,...          22050  normal
# 346  [-0.007578952, -0.011004641, -0.015165693, -0....          22050  normal
# 410  [-0.030912954, -0.033952978, -0.035377894, -0....          22050  normal

# %% [markdown]
# ## Dataset Augmentation
#
# We won't get very far with the examples we have. There aren't very many of them
#
# Luckily, we can easily augment the dataset by shifting the data and/or adding some noise

# %%
DATASET_TARGET = 1000

# %%
# find the label ratios
inverse_counts = 1/train_dataset['label'].value_counts()
probability_counts = inverse_counts/inverse_counts.sum()
probability_counts
# Out:
# normal      0.468852
# abnormal    0.531148
# Name: label, dtype: float64

# %%
#https://medium.com/@makcedward/data-augmentation-for-audio-76912b01fdf6
    
def shift_sound(data, sampling_rate, shift_max, shift_direction='right'):
    shift = np.random.randint(int(shift_max * data.shape[0]))
    if shift_direction == 'right':
        shift = -shift
    elif shift_direction == 'both':
        direction = np.random.randint(0, 2)
        if direction == 1:
            shift = -shift
    augmented_data = np.roll(data, shift)
    # Set to silence for heading/ tailing
    if shift > 0:
        augmented_data = augmented_data[shift:]
    else:
        augmented_data = augmented_data[:shift]
    return augmented_data

# %%
choices = np.random.choice(probability_counts.index, 
                           p=probability_counts.values, 
                           size=(DATASET_TARGET,))
i = 0
while train_dataset.shape[0] < DATASET_TARGET:
    choice = choices[i]
    available_instances = train_dataset[train_dataset['label'] == choice]
    selected_row_position = np.random.randint(available_instances.shape[0])
    
    selected_row = available_instances.iloc[selected_row_position]
    
    base_signal = selected_row['signal']
    sampling_rate = selected_row['sampling_rate']
    
    shift_direction = 'both'
    new_signal = shift_sound(base_signal, sampling_rate, (np.random.random()*0.3), shift_direction)
    if (new_signal.shape[0] > 0):
    
        new_series = pd.Series({'signal' :new_signal, 'sampling_rate': sampling_rate, 'label': choice})
        train_dataset = train_dataset.append(new_series, ignore_index=True)
    
        print(train_dataset.shape, end="\r")
    i+= 1
# Out:
# (1000, 3)

# %% [markdown]
# Now let's define a class which will convert the signals into Mel spectrograms

# %%
class MelEncoder:
    
    def __init__(self, flatten=True, n_fft=2048, hop_length=512, n_mels=128, sampling_rate=22050.0, n_windows=1000, verbose=0):
        self.n_fft = n_fft
        self.hop_length = hop_length
        self.n_mels = n_mels
        self.sampling_rate = sampling_rate
        self.n_windows = n_windows
        self.verbose = verbose
        
        
        self.flatten = flatten
        
    
    def fit(self, X, y=None):
        self.longest_signal = None
        
    
    def transform(self, X):
        X_list = []
        
        
        for i, signal in enumerate(X):
            try:
                mel_spectrogram = self._signal_to_mel_spectrogram(signal)
                X_list.append(mel_spectrogram)
                if (self.verbose):
                    print(f"{round(100*i/X.shape[0], 2)}%")
            except ValueError as e:
                print(signal)
                print(signal.shape)
                plt.figure()
                plt.plot(signal)
                plt.show()
                raise e
            
            
        if (self.longest_signal is None):
            max_length = 0
            for mel_spectrogram in X_list:
                if (mel_spectrogram.shape[1] > max_length):
                    max_length = mel_spectrogram.shape[1]
                    
            self.longest_signal = max_length
        else:
            max_length = self.longest_signal
                
        X_transformed = np.zeros((len(X_list), self.n_mels, max_length))
        
        for i, mel_spectrogram in enumerate(X_list):
            if (mel_spectrogram.shape[1] <= max_length):
                X_transformed[i, :, -mel_spectrogram.shape[1]:] = mel_spectrogram[:, :]
            else:
                X_transformed[i, :, :] = mel_spectrogram[:, -max_length:]
            
            
            
            
        
        #X_transformed = np.array(X_list)
        
        
        
        if (self.flatten):
            return X_transformed.reshape(X_transformed.shape[0], -1)
        else:
            return X_transformed
        
        
    def fit_transform(self, X, y=None):
        return self.fit(X).transform(X)
        
        
        
        
    # https://towardsdatascience.com/getting-to-know-the-mel-spectrogram-31bca3e2d9d0
    def _longest_signal(self, signals):
        max_length = 0
        for signal in signals:
            if (len(signal) > max_length):
                max_length = len(signal)

        return max_length
    
    
    def _signal_to_mel_spectrogram(self, signal):
        
        
        if (self.n_windows is not None):
            hop_length = signal.shape[0]//self.n_windows
        else:
            hop_length = self.hop_length
        S = librosa.feature.melspectrogram(signal, 
                                           sr=self.sampling_rate, 
                                           n_fft=self.n_fft, 
                                           hop_length=hop_length, 
                                           n_mels=self.n_mels)
        S_DB = librosa.power_to_db(S, ref=np.max)
        return S_DB

# %%
my_encoder = MelEncoder(n_mels=128, n_windows=1000)

# %%
my_encoder.fit(train_dataset['signal'])

# %%
X_train_mel = my_encoder.transform(train_dataset['signal'])

# %%
X_train_mel.shape
# Out:
# (1000, 134400)

# %%
X_test_mel = my_encoder.transform(test_dataset['signal'])

# %%
X_test_mel.shape
# Out:
# (131, 134400)

# %% [markdown]
# ## PCA

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
my_mmscaler = MinMaxScaler()

X_train_mel = my_mmscaler.fit_transform(X_train_mel)
X_test_mel = my_mmscaler.transform(X_test_mel)

# %%
X_train_mel = X_train_mel
X_train_mel.shape
# Out:
# (1000, 134400)

# %%
# %%time 

component_number = min(*X_train_mel.shape)
my_pca = PCA(n_components=component_number, svd_solver='randomized')
my_pca.fit(X_train_mel)
# Out:
# Wall time: 2min 44s
# PCA(n_components=1000, svd_solver='randomized')

# %%
plt.figure(figsize=(15,5))
plt.plot(my_pca.explained_variance_ratio_.cumsum())
plt.show()

# %%
X_train_mel = my_pca.transform(X_train_mel)
X_test_mel = my_pca.transform(X_test_mel)

# %%
X_train_mel.shape
# Out:
# (1000, 1000)

# %%
X_test_mel.shape
# Out:
# (131, 1000)

# %% [markdown]
# ## Basic Model - Logistic Regression
#
# Let's start by establishing a baseline performance. I am just going to load the raw audio data as features (where each feature is an audio measurement) and see how well a simple logistic regression (linear model) and decision tree (non-linear model) will perform

# %%
condition_label_encoder = LabelEncoder()


y_train = condition_label_encoder.fit_transform(train_dataset['label'])[:X_train_mel.shape[0]]
y_test = condition_label_encoder.transform(test_dataset['label'])

print(X_train_mel.shape, X_test_mel.shape)
print(y_train.shape, y_test.shape)
# Out:
# (1000, 1000) (131, 1000)
# (1000,) (131,)

# %%
# %%time

my_logit = LogisticRegression(random_state=1).fit(X_train_mel, y_train)
train_acc = my_logit.score(X_train_mel, y_train)
test_acc = my_logit.score(X_test_mel, y_test)
# Out:
# Wall time: 1.11 s

# %%
print(f"The training accuracy is {round(train_acc*100,2)}%")
print(f"The test accuracy is {round(test_acc*100,2)}%")
# Out:
# The training accuracy is 100.0%
# The test accuracy is 60.31%

# %% [markdown]
# Extremely suspicious results. There is clearly a very large sign of overfitting here. Let's explore how the logistic regression makes decisions.
#
# Let's plot the coefficients as if they were an audio mask (which is really what they end up becoming).

# %%
figure, ax = plt.subplots(figsize=(7, 7))
disp = plot_confusion_matrix(my_logit, X_test_mel, y_test,
                             display_labels = condition_label_encoder.classes_,
                             cmap=plt.cm.Blues,
                             normalize=None,
                             ax=ax)
disp.ax_.set_title("Logit Confusion Matrix")
plt.show()

# %%
figure, ax = plt.subplots(figsize=(7, 7))
disp = plot_confusion_matrix(my_logit, X_test_mel, y_test,
                             display_labels=condition_label_encoder.classes_,
                             cmap=plt.cm.Blues,
                             normalize='true',
                             ax=ax)
disp.ax_.set_title("Logit Confusion Matrix")
plt.show()

# %%
param_grid = {'penalty': ['l1', 'l2'],
              'C': [10**i for i in range(-7, 8)]}
my_estimator = LogisticRegression(solver='saga')
my_gs = GridSearchCV(my_estimator, param_grid, cv=5, verbose=2)

# %%
# %%time
my_gs.fit(X_train_mel, y_train);
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [CV] C=1e-07, penalty=l1 .............................................
# [CV] .............................. C=1e-07, penalty=l1, total=   0.0s
# [CV] C=1e-07, penalty=l1 .............................................
# [CV] .............................. C=1e-07, penalty=l1, total=   0.0s
# [CV] C=1e-07, penalty=l1 .............................................
# [CV] .............................. C=1e-07, penalty=l1, total=   0.0s
# [CV] C=1e-07, penalty=l1 .............................................
# [CV] .............................. C=1e-07, penalty=l1, total=   0.0s
# [CV] C=1e-07, penalty=l1 .............................................
# [CV] .............................. C=1e-07, penalty=l1, total=   0.0s
# [CV] C=1e-07, penalty=l2 .............................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [CV] .............................. C=1e-07, penalty=l2, total=   0.8s
# [CV] C=1e-07, penalty=l2 .............................................
# [CV] .............................. C=1e-07, penalty=l2, total=   0.7s
# [CV] C=1e-07, penalty=l2 .............................................
# [CV] .............................. C=1e-07, penalty=l2, total=   0.7s
# [CV] C=1e-07, penalty=l2 .............................................
# [CV] .............................. C=1e-07, penalty=l2, total=   0.8s
# [CV] C=1e-07, penalty=l2 .............................................
# [CV] .............................. C=1e-07, penalty=l2, total=   0.7s
# [CV] C=1e-06, penalty=l1 .............................................
# [CV] .............................. C=1e-06, penalty=l1, total=   0.0s
# [CV] C=1e-06, penalty=l1 .............................................
# [CV] .............................. C=1e-06, penalty=l1, total=   0.0s
# [CV] C=1e-06, penalty=l1 .............................................
# [CV] .............................. C=1e-06, penalty=l1, total=   0.0s
# [CV] C=1e-06, penalty=l1 .............................................
# [CV] .............................. C=1e-06, penalty=l1, total=   0.0s
# [CV] C=1e-06, penalty=l1 .............................................
# [CV] .............................. C=1e-06, penalty=l1, total=   0.0s
# [CV] C=1e-06, penalty=l2 .............................................
# [CV] .............................. C=1e-06, penalty=l2, total=   0.7s
# [CV] C=1e-06, penalty=l2 .............................................
# [CV] .............................. C=1e-06, penalty=l2, total=   0.8s
# [CV] C=1e-06, penalty=l2 .............................................
# [CV] .............................. C=1e-06, penalty=l2, total=   0.6s
# [CV] C=1e-06, penalty=l2 .............................................
# [CV] .............................. C=1e-06, penalty=l2, total=   0.8s
# [CV] C=1e-06, penalty=l2 .............................................
# [CV] .............................. C=1e-06, penalty=l2, total=   0.4s
# [CV] C=1e-05, penalty=l1 .............................................
# [CV] .............................. C=1e-05, penalty=l1, total=   0.0s
# [CV] C=1e-05, penalty=l1 .............................................
# [CV] .............................. C=1e-05, penalty=l1, total=   0.0s
# [CV] C=1e-05, penalty=l1 .............................................
# [CV] .............................. C=1e-05, penalty=l1, total=   0.0s
# [CV] C=1e-05, penalty=l1 .............................................
# [CV] .............................. C=1e-05, penalty=l1, total=   0.0s
# [CV] C=1e-05, penalty=l1 .............................................
# [CV] .............................. C=1e-05, penalty=l1, total=   0.0s
# [CV] C=1e-05, penalty=l2 .............................................
# [CV] .............................. C=1e-05, penalty=l2, total=   0.1s
# [CV] C=1e-05, penalty=l2 .............................................
# [CV] .............................. C=1e-05, penalty=l2, total=   0.2s
# [CV] C=1e-05, penalty=l2 .............................................
# [CV] .............................. C=1e-05, penalty=l2, total=   0.5s
# [CV] C=1e-05, penalty=l2 .............................................
# [CV] .............................. C=1e-05, penalty=l2, total=   0.2s
# [CV] C=1e-05, penalty=l2 .............................................
# [CV] .............................. C=1e-05, penalty=l2, total=   0.4s
# [CV] C=0.0001, penalty=l1 ............................................
# [CV] ............................. C=0.0001, penalty=l1, total=   0.0s
# [CV] C=0.0001, penalty=l1 ............................................
# [CV] ............................. C=0.0001, penalty=l1, total=   0.0s
# [CV] C=0.0001, penalty=l1 ............................................
# [CV] ............................. C=0.0001, penalty=l1, total=   0.0s
# [CV] C=0.0001, penalty=l1 ............................................
# [CV] ............................. C=0.0001, penalty=l1, total=   0.0s
# [CV] C=0.0001, penalty=l1 ............................................
# [CV] ............................. C=0.0001, penalty=l1, total=   0.0s
# [CV] C=0.0001, penalty=l2 ............................................
# [CV] ............................. C=0.0001, penalty=l2, total=   0.3s
# [CV] C=0.0001, penalty=l2 ............................................
# [CV] ............................. C=0.0001, penalty=l2, total=   0.2s
# [CV] C=0.0001, penalty=l2 ............................................
# [CV] ............................. C=0.0001, penalty=l2, total=   0.3s
# [CV] C=0.0001, penalty=l2 ............................................
# [CV] ............................. C=0.0001, penalty=l2, total=   0.3s
# [CV] C=0.0001, penalty=l2 ............................................
# [CV] ............................. C=0.0001, penalty=l2, total=   0.3s
# [CV] C=0.001, penalty=l1 .............................................
# [CV] .............................. C=0.001, penalty=l1, total=   0.2s
# [CV] C=0.001, penalty=l1 .............................................
# [CV] .............................. C=0.001, penalty=l1, total=   0.3s
# [CV] C=0.001, penalty=l1 .............................................
# [CV] .............................. C=0.001, penalty=l1, total=   1.0s
# [CV] C=0.001, penalty=l1 .............................................
# [CV] .............................. C=0.001, penalty=l1, total=   0.4s
# [CV] C=0.001, penalty=l1 .............................................
# [CV] .............................. C=0.001, penalty=l1, total=   0.5s
# [CV] C=0.001, penalty=l2 .............................................
# [CV] .............................. C=0.001, penalty=l2, total=   0.8s
# [CV] C=0.001, penalty=l2 .............................................
# [CV] .............................. C=0.001, penalty=l2, total=   0.8s
# [CV] C=0.001, penalty=l2 .............................................
# [CV] .............................. C=0.001, penalty=l2, total=   0.8s
# [CV] C=0.001, penalty=l2 .............................................
# [CV] .............................. C=0.001, penalty=l2, total=   0.8s
# [CV] C=0.001, penalty=l2 .............................................
# [CV] .............................. C=0.001, penalty=l2, total=   0.8s
# [CV] C=0.01, penalty=l1 ..............................................
# [CV] ............................... C=0.01, penalty=l1, total=   1.0s
# [CV] C=0.01, penalty=l1 ..............................................
# [CV] ............................... C=0.01, penalty=l1, total=   1.0s
# [CV] C=0.01, penalty=l1 ..............................................
# [CV] ............................... C=0.01, penalty=l1, total=   1.0s
# [CV] C=0.01, penalty=l1 ..............................................
# [CV] ............................... C=0.01, penalty=l1, total=   1.0s
# [CV] C=0.01, penalty=l1 ..............................................
# [CV] ............................... C=0.01, penalty=l1, total=   1.0s
# [CV] C=0.01, penalty=l2 ..............................................
# [CV] ............................... C=0.01, penalty=l2, total=   0.8s
# [CV] C=0.01, penalty=l2 ..............................................
# [CV] ............................... C=0.01, penalty=l2, total=   0.8s
# [CV] C=0.01, penalty=l2 ..............................................
# [CV] ............................... C=0.01, penalty=l2, total=   0.8s
# [CV] C=0.01, penalty=l2 ..............................................
# [CV] ............................... C=0.01, penalty=l2, total=   0.8s
# [CV] C=0.01, penalty=l2 ..............................................
# [CV] ............................... C=0.01, penalty=l2, total=   0.7s
# [CV] C=0.1, penalty=l1 ...............................................
# [CV] ................................ C=0.1, penalty=l1, total=   1.1s
# [CV] C=0.1, penalty=l1 ...............................................
# [CV] ................................ C=0.1, penalty=l1, total=   1.1s
# [CV] C=0.1, penalty=l1 ...............................................
# [CV] ................................ C=0.1, penalty=l1, total=   1.1s
# [CV] C=0.1, penalty=l1 ...............................................
# [CV] ................................ C=0.1, penalty=l1, total=   1.1s
# [CV] C=0.1, penalty=l1 ...............................................
# [CV] ................................ C=0.1, penalty=l1, total=   1.0s
# [CV] C=0.1, penalty=l2 ...............................................
# [CV] ................................ C=0.1, penalty=l2, total=   0.8s
# [CV] C=0.1, penalty=l2 ...............................................
# [CV] ................................ C=0.1, penalty=l2, total=   0.8s
# [CV] C=0.1, penalty=l2 ...............................................
# [CV] ................................ C=0.1, penalty=l2, total=   0.8s
# [CV] C=0.1, penalty=l2 ...............................................
# [CV] ................................ C=0.1, penalty=l2, total=   0.8s
# [CV] C=0.1, penalty=l2 ...............................................
# [CV] ................................ C=0.1, penalty=l2, total=   0.8s
# [CV] C=1, penalty=l1 .................................................
# [CV] .................................. C=1, penalty=l1, total=   1.5s
# [CV] C=1, penalty=l1 .................................................
# [CV] .................................. C=1, penalty=l1, total=   1.5s
# [CV] C=1, penalty=l1 .................................................
# [CV] .................................. C=1, penalty=l1, total=   1.6s
# [CV] C=1, penalty=l1 .................................................
# [CV] .................................. C=1, penalty=l1, total=   1.5s
# [CV] C=1, penalty=l1 .................................................
# [CV] .................................. C=1, penalty=l1, total=   1.5s
# [CV] C=1, penalty=l2 .................................................
# [CV] .................................. C=1, penalty=l2, total=   0.8s
# [CV] C=1, penalty=l2 .................................................
# [CV] .................................. C=1, penalty=l2, total=   0.8s
# [CV] C=1, penalty=l2 .................................................
# [CV] .................................. C=1, penalty=l2, total=   0.8s
# [CV] C=1, penalty=l2 .................................................
# [CV] .................................. C=1, penalty=l2, total=   0.8s
# [CV] C=1, penalty=l2 .................................................
# [CV] .................................. C=1, penalty=l2, total=   0.8s
# [CV] C=10, penalty=l1 ................................................
# [CV] ................................. C=10, penalty=l1, total=   1.6s
# [CV] C=10, penalty=l1 ................................................
# [CV] ................................. C=10, penalty=l1, total=   1.6s
# [CV] C=10, penalty=l1 ................................................
# [CV] ................................. C=10, penalty=l1, total=   1.7s
# [CV] C=10, penalty=l1 ................................................
# [CV] ................................. C=10, penalty=l1, total=   1.8s
# [CV] C=10, penalty=l1 ................................................
# [CV] ................................. C=10, penalty=l1, total=   1.6s
# [CV] C=10, penalty=l2 ................................................
# [CV] ................................. C=10, penalty=l2, total=   0.8s
# [CV] C=10, penalty=l2 ................................................
# [CV] ................................. C=10, penalty=l2, total=   0.8s
# [CV] C=10, penalty=l2 ................................................
# [CV] ................................. C=10, penalty=l2, total=   0.8s
# [CV] C=10, penalty=l2 ................................................
# [CV] ................................. C=10, penalty=l2, total=   0.8s
# [CV] C=10, penalty=l2 ................................................
# [CV] ................................. C=10, penalty=l2, total=   0.8s
# [CV] C=100, penalty=l1 ...............................................
# [CV] ................................ C=100, penalty=l1, total=   1.7s
# [CV] C=100, penalty=l1 ...............................................
# [CV] ................................ C=100, penalty=l1, total=   1.8s
# [CV] C=100, penalty=l1 ...............................................
# [CV] ................................ C=100, penalty=l1, total=   1.7s
# [CV] C=100, penalty=l1 ...............................................
# [CV] ................................ C=100, penalty=l1, total=   1.7s
# [CV] C=100, penalty=l1 ...............................................
# [CV] ................................ C=100, penalty=l1, total=   1.7s
# [CV] C=100, penalty=l2 ...............................................
# [CV] ................................ C=100, penalty=l2, total=   0.8s
# [CV] C=100, penalty=l2 ...............................................
# [CV] ................................ C=100, penalty=l2, total=   0.8s
# [CV] C=100, penalty=l2 ...............................................
# [CV] ................................ C=100, penalty=l2, total=   0.8s
# [CV] C=100, penalty=l2 ...............................................
# [CV] ................................ C=100, penalty=l2, total=   0.8s
# [CV] C=100, penalty=l2 ...............................................
# [CV] ................................ C=100, penalty=l2, total=   0.8s
# [CV] C=1000, penalty=l1 ..............................................
# [CV] ............................... C=1000, penalty=l1, total=   1.7s
# [CV] C=1000, penalty=l1 ..............................................
# [CV] ............................... C=1000, penalty=l1, total=   1.8s
# [CV] C=1000, penalty=l1 ..............................................
# [CV] ............................... C=1000, penalty=l1, total=   1.8s
# [CV] C=1000, penalty=l1 ..............................................
# [CV] ............................... C=1000, penalty=l1, total=   1.7s
# [CV] C=1000, penalty=l1 ..............................................
# [CV] ............................... C=1000, penalty=l1, total=   1.7s
# [CV] C=1000, penalty=l2 ..............................................
# [CV] ............................... C=1000, penalty=l2, total=   0.9s
# [CV] C=1000, penalty=l2 ..............................................
# [CV] ............................... C=1000, penalty=l2, total=   0.9s
# [CV] C=1000, penalty=l2 ..............................................
# [CV] ............................... C=1000, penalty=l2, total=   0.8s
# [CV] C=1000, penalty=l2 ..............................................
# [CV] ............................... C=1000, penalty=l2, total=   0.8s
# [CV] C=1000, penalty=l2 ..............................................
# [CV] ............................... C=1000, penalty=l2, total=   0.8s
# [CV] C=10000, penalty=l1 .............................................
# [CV] .............................. C=10000, penalty=l1, total=   1.9s
# [CV] C=10000, penalty=l1 .............................................
# [CV] .............................. C=10000, penalty=l1, total=   1.9s
# [CV] C=10000, penalty=l1 .............................................
# [CV] .............................. C=10000, penalty=l1, total=   1.8s
# [CV] C=10000, penalty=l1 .............................................
# [CV] .............................. C=10000, penalty=l1, total=   1.8s
# [CV] C=10000, penalty=l1 .............................................
# [CV] .............................. C=10000, penalty=l1, total=   1.8s
# [CV] C=10000, penalty=l2 .............................................
# [CV] .............................. C=10000, penalty=l2, total=   0.8s
# [CV] C=10000, penalty=l2 .............................................
# [CV] .............................. C=10000, penalty=l2, total=   0.8s
# [CV] C=10000, penalty=l2 .............................................
# [CV] .............................. C=10000, penalty=l2, total=   0.8s
# [CV] C=10000, penalty=l2 .............................................
# [CV] .............................. C=10000, penalty=l2, total=   0.8s
# [CV] C=10000, penalty=l2 .............................................
# [CV] .............................. C=10000, penalty=l2, total=   0.8s
# [CV] C=100000, penalty=l1 ............................................
# [CV] ............................. C=100000, penalty=l1, total=   1.8s
# [CV] C=100000, penalty=l1 ............................................
# [CV] ............................. C=100000, penalty=l1, total=   1.8s
# [CV] C=100000, penalty=l1 ............................................
# [CV] ............................. C=100000, penalty=l1, total=   1.8s
# [CV] C=100000, penalty=l1 ............................................
# [CV] ............................. C=100000, penalty=l1, total=   1.8s
# [CV] C=100000, penalty=l1 ............................................
# [CV] ............................. C=100000, penalty=l1, total=   1.8s
# [CV] C=100000, penalty=l2 ............................................
# [CV] ............................. C=100000, penalty=l2, total=   0.8s
# [CV] C=100000, penalty=l2 ............................................
# [CV] ............................. C=100000, penalty=l2, total=   0.8s
# [CV] C=100000, penalty=l2 ............................................
# [CV] ............................. C=100000, penalty=l2, total=   0.9s
# [CV] C=100000, penalty=l2 ............................................
# [CV] ............................. C=100000, penalty=l2, total=   0.8s
# [CV] C=100000, penalty=l2 ............................................
# [CV] ............................. C=100000, penalty=l2, total=   0.8s
# [CV] C=1000000, penalty=l1 ...........................................
# [CV] ............................ C=1000000, penalty=l1, total=   1.8s
# [CV] C=1000000, penalty=l1 ...........................................
# [CV] ............................ C=1000000, penalty=l1, total=   1.8s
# [CV] C=1000000, penalty=l1 ...........................................
# [CV] ............................ C=1000000, penalty=l1, total=   1.8s
# [CV] C=1000000, penalty=l1 ...........................................
# [CV] ............................ C=1000000, penalty=l1, total=   1.8s
# [CV] C=1000000, penalty=l1 ...........................................
# [CV] ............................ C=1000000, penalty=l1, total=   1.7s
# [CV] C=1000000, penalty=l2 ...........................................
# [CV] ............................ C=1000000, penalty=l2, total=   0.9s
# [CV] C=1000000, penalty=l2 ...........................................
# [CV] ............................ C=1000000, penalty=l2, total=   0.8s
# [CV] C=1000000, penalty=l2 ...........................................
# [CV] ............................ C=1000000, penalty=l2, total=   0.8s
# [CV] C=1000000, penalty=l2 ...........................................
# [CV] ............................ C=1000000, penalty=l2, total=   0.8s
# [CV] C=1000000, penalty=l2 ...........................................
# [CV] ............................ C=1000000, penalty=l2, total=   0.8s
# [CV] C=10000000, penalty=l1 ..........................................
# [CV] ........................... C=10000000, penalty=l1, total=   1.8s
# [CV] C=10000000, penalty=l1 ..........................................
# [CV] ........................... C=10000000, penalty=l1, total=   1.8s
# [CV] C=10000000, penalty=l1 ..........................................
# [CV] ........................... C=10000000, penalty=l1, total=   1.9s
# [CV] C=10000000, penalty=l1 ..........................................
# [CV] ........................... C=10000000, penalty=l1, total=   1.8s
# [CV] C=10000000, penalty=l1 ..........................................
# [CV] ........................... C=10000000, penalty=l1, total=   1.8s
# [CV] C=10000000, penalty=l2 ..........................................
# [CV] ........................... C=10000000, penalty=l2, total=   0.8s
# [CV] C=10000000, penalty=l2 ..........................................
# [CV] ........................... C=10000000, penalty=l2, total=   0.8s
# [CV] C=10000000, penalty=l2 ..........................................
# [CV] ........................... C=10000000, penalty=l2, total=   0.8s
# [CV] C=10000000, penalty=l2 ..........................................
# [CV] ........................... C=10000000, penalty=l2, total=   0.8s
# [CV] C=10000000, penalty=l2 ..........................................
# [CV] ........................... C=10000000, penalty=l2, total=   0.8s
# [Parallel(n_jobs=1)]: Done 150 out of 150 | elapsed:  2.3min finished
# Wall time: 2min 17s
# GridSearchCV(cv=5, estimator=LogisticRegression(solver='saga'),
#              param_grid={'C': [1e-07, 1e-06, 1e-05, 0.0001, 0.001, 0.01, 0.1, 1,
#                                10, 100, 1000, 10000, 100000, 1000000,
#                                10000000],
#                          'penalty': ['l1', 'l2']},
#              verbose=2)

# %%
my_gs.best_params_
# Out:
# {'C': 0.1, 'penalty': 'l2'}

# %%
my_gs.score(X_test_mel, y_test)
# Out:
# 0.6106870229007634

# %%
train_acc = my_gs.score(X_train_mel, y_train)
test_acc = my_gs.score(X_test_mel, y_test)

# %%
print(f"The training accuracy is {round(train_acc*100,2)}%")
print(f"The test accuracy is {round(test_acc*100,2)}%")
# Out:
# The training accuracy is 86.2%
# The test accuracy is 61.07%

# %%
figure, ax = plt.subplots(figsize=(7, 7))
disp = plot_confusion_matrix(my_gs, X_test_mel, y_test,
                             display_labels = condition_label_encoder.classes_,
                             cmap=plt.cm.Blues,
                             normalize=None,
                             ax=ax)
disp.ax_.set_title("Logit Confusion Matrix")
plt.show()

# %%
figure, ax = plt.subplots(figsize=(7, 7))
disp = plot_confusion_matrix(my_gs, X_test_mel, y_test,
                             display_labels=condition_label_encoder.classes_,
                             cmap=plt.cm.Blues,
                             normalize='true',
                             ax=ax)
disp.ax_.set_title("Logit Confusion Matrix")
plt.show()

# %%
print(classification_report(y_test, my_gs.predict(X_test_mel)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.58      0.61      0.60        62
#            1       0.64      0.61      0.62        69
#
#     accuracy                           0.61       131
#    macro avg       0.61      0.61      0.61       131
# weighted avg       0.61      0.61      0.61       131

# %% [markdown]
# ## Basic Model - Decision Tree
#
# As another baseline, I will train a decision tree to see if introducing non-linearity to the learning process produces better results

# %%
print(X_train_mel.shape, X_test_mel.shape)
print(y_train.shape, y_test.shape)
# Out:
# (1000, 1000) (131, 1000)
# (1000,) (131,)

# %%
# %%time 

# Let's set some regularization otherwise we know the tree will overfit
my_tree = DecisionTreeClassifier()
param_grid = {'min_samples_leaf': [i for i in range(1, 20)],
              'max_depth' : [i for i in range(1, 20)]+[None],
              'max_features': [i/10 for i in range(1, 11)]}

my_tree_gs = GridSearchCV(my_tree, param_grid, cv=5, verbose=2)
my_tree_gs.fit(X_train_mel, y_train)


train_acc = my_tree_gs.score(X_train_mel, y_train)
test_acc = my_tree_gs.score(X_test_mel, y_test)
# Out:
# Fitting 5 folds for each of 3800 candidates, totalling 19000 fits
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=1 ...............
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=1, total=   0.3s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=1 ...............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=1, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=1 ...............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=1, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=1 ...............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=1, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=1 ...............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=1, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=2 ...............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=2, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=2 ...............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=2, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=2 ...............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=2, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=2 ...............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=2, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=2 ...............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=2, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=3 ...............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=3, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=3 ...............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=3, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=3 ...............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=3, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=3 ...............
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=3, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=3 ...............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=3, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=4 ...............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=4, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=4 ...............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=4, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=4 ...............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=4, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=4 ...............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=4, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=4 ...............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=4, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=5 ...............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=5, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=5 ...............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=5, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=5 ...............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=5, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=5 ...............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=5, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=5 ...............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=5, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=6 ...............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=6, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=6 ...............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=6, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=6 ...............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=6, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=6 ...............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=6, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=6 ...............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=6, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=7 ...............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=7, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=7 ...............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=7, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=7 ...............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=7, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=7 ...............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=7, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=7 ...............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=7, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=8 ...............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=8, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=8 ...............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=8, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=8 ...............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=8, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=8 ...............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=8, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=8 ...............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=8, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=9 ...............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=9, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=9 ...............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=9, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=9 ...............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=9, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=9 ...............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=9, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=9 ...............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=9, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=10 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=10, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=10 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=10, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=10 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=10, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=10 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=10, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=10 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=10, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=11 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=11, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=11 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=11, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=11 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=11, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=11 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=11, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=11 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=11, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=12 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=12, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=12 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=12, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=12 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=12, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=12 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=12, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=12 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=12, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=13 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=13, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=13 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=13, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=13 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=13, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=13 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=13, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=13 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=13, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=14 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=14, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=14 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=14, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=14 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=14, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=14 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=14, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=14 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=14, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=15 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=15, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=15 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=15, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=15 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=15, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=15 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=15, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=15 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=15, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=16 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=16, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=16 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=16, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=16 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=16, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=16 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=16, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=16 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=16, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=17 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=17, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=17 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=17, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=17 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=17, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=17 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=17, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=17 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=17, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=18 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=18, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=18 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=18, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=18 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=18, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=18 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=18, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=18 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=18, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=19 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=19, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=19 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=19, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=19 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=19, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=19 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=19, total=   0.0s
# [CV] max_depth=1, max_features=0.1, min_samples_leaf=19 ..............
# [CV]  max_depth=1, max_features=0.1, min_samples_leaf=19, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=1 ...............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=1, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=1 ...............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=1, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=1 ...............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=1, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=1 ...............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=1, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=1 ...............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=1, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=2 ...............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=2, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=2 ...............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=2, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=2 ...............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=2, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=2 ...............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=2, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=2 ...............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=2, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=3 ...............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=3, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=3 ...............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=3, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=3 ...............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=3, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=3 ...............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=3, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=3 ...............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=3, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=4 ...............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=4, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=4 ...............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=4, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=4 ...............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=4, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=4 ...............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=4, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=4 ...............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=4, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=5 ...............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=5, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=5 ...............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=5, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=5 ...............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=5, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=5 ...............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=5, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=5 ...............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=5, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=6 ...............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=6, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=6 ...............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=6, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=6 ...............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=6, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=6 ...............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=6, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=6 ...............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=6, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=7 ...............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=7, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=7 ...............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=7, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=7 ...............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=7, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=7 ...............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=7, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=7 ...............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=7, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=8 ...............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=8, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=8 ...............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=8, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=8 ...............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=8, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=8 ...............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=8, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=8 ...............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=8, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=9 ...............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=9, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=9 ...............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=9, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=9 ...............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=9, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=9 ...............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=9, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=9 ...............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=9, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=10 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=10, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=10 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=10, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=10 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=10, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=10 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=10, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=10 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=10, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=11 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=11, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=11 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=11, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=11 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=11, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=11 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=11, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=11 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=11, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=12 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=12, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=12 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=12, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=12 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=12, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=12 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=12, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=12 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=12, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=13 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=13, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=13 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=13, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=13 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=13, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=13 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=13, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=13 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=13, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=14 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=14, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=14 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=14, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=14 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=14, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=14 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=14, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=14 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=14, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=15 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=15, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=15 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=15, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=15 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=15, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=15 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=15, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=15 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=15, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=16 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=16, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=16 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=16, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=16 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=16, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=16 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=16, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=16 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=16, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=17 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=17, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=17 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=17, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=17 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=17, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=17 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=17, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=17 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=17, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=18 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=18, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=18 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=18, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=18 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=18, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=18 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=18, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=18 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=18, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=19 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=19, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=19 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=19, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=19 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=19, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=19 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=19, total=   0.0s
# [CV] max_depth=1, max_features=0.2, min_samples_leaf=19 ..............
# [CV]  max_depth=1, max_features=0.2, min_samples_leaf=19, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=1 ...............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=1, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=1 ...............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=1, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=1 ...............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=1, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=1 ...............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=1, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=1 ...............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=1, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=2 ...............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=2, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=2 ...............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=2, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=2 ...............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=2, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=2 ...............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=2, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=2 ...............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=2, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=3 ...............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=3, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=3 ...............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=3, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=3 ...............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=3, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=3 ...............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=3, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=3 ...............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=3, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=4 ...............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=4, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=4 ...............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=4, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=4 ...............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=4, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=4 ...............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=4, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=4 ...............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=4, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=5 ...............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=5, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=5 ...............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=5, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=5 ...............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=5, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=5 ...............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=5, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=5 ...............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=5, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=6 ...............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=6, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=6 ...............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=6, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=6 ...............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=6, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=6 ...............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=6, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=6 ...............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=6, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=7 ...............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=7, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=7 ...............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=7, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=7 ...............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=7, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=7 ...............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=7, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=7 ...............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=7, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=8 ...............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=8, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=8 ...............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=8, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=8 ...............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=8, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=8 ...............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=8, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=8 ...............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=8, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=9 ...............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=9, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=9 ...............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=9, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=9 ...............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=9, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=9 ...............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=9, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=9 ...............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=9, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=10 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=10, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=10 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=10, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=10 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=10, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=10 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=10, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=10 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=10, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=11 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=11, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=11 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=11, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=11 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=11, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=11 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=11, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=11 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=11, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=12 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=12, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=12 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=12, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=12 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=12, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=12 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=12, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=12 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=12, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=13 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=13, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=13 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=13, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=13 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=13, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=13 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=13, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=13 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=13, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=14 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=14, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=14 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=14, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=14 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=14, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=14 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=14, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=14 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=14, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=15 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=15, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=15 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=15, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=15 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=15, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=15 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=15, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=15 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=15, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=16 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=16, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=16 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=16, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=16 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=16, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=16 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=16, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=16 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=16, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=17 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=17, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=17 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=17, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=17 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=17, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=17 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=17, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=17 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=17, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=18 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=18, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=18 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=18, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=18 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=18, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=18 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=18, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=18 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=18, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=19 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=19, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=19 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=19, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=19 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=19, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=19 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=19, total=   0.0s
# [CV] max_depth=1, max_features=0.3, min_samples_leaf=19 ..............
# [CV]  max_depth=1, max_features=0.3, min_samples_leaf=19, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=1 ...............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=1, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=1 ...............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=1, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=1 ...............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=1, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=1 ...............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=1, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=1 ...............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=1, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=2 ...............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=2, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=2 ...............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=2, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=2 ...............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=2, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=2 ...............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=2, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=2 ...............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=2, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=3 ...............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=3, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=3 ...............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=3, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=3 ...............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=3, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=3 ...............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=3, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=3 ...............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=3, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=4 ...............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=4, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=4 ...............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=4, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=4 ...............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=4, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=4 ...............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=4, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=4 ...............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=4, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=5 ...............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=5, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=5 ...............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=5, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=5 ...............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=5, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=5 ...............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=5, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=5 ...............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=5, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=6 ...............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=6, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=6 ...............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=6, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=6 ...............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=6, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=6 ...............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=6, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=6 ...............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=6, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=7 ...............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=7, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=7 ...............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=7, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=7 ...............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=7, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=7 ...............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=7, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=7 ...............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=7, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=8 ...............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=8, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=8 ...............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=8, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=8 ...............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=8, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=8 ...............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=8, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=8 ...............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=8, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=9 ...............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=9, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=9 ...............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=9, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=9 ...............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=9, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=9 ...............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=9, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=9 ...............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=9, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=10 ..............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=10, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=10 ..............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=10, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=10 ..............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=10, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=10 ..............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=10, total=   0.0s
# [CV] max_depth=1, max_features=0.4, min_samples_leaf=10 ..............
# [CV]  max_depth=1, max_features=0.4, min_samples_leaf=10, total=   0.0s
# ...
# [CV]  max_depth=1, max_features=1.0, min_samples_leaf=17, total=   0.1s
# [CV] max_depth=1, max_features=1.0, min_samples_leaf=17 ..............
# [CV]  max_depth=1, max_features=1.0, min_samples_leaf=17, total=   0.1s
# [CV] max_depth=1, max_features=1.0, min_samples_leaf=18 ..............
# [CV]  max_depth=1, max_features=1.0, min_samples_leaf=18, total=   0.1s
# [CV] max_depth=1, max_features=1.0, min_samples_leaf=18 ..............
# [CV]  max_depth=1, max_features=1.0, min_samples_leaf=18, total=   0.1s
# [CV] max_depth=1, max_features=1.0, min_samples_leaf=18 ..............
# [CV]  max_depth=1, max_features=1.0, min_samples_leaf=18, total=   0.1s
# [CV] max_depth=1, max_features=1.0, min_samples_leaf=18 ..............
# [CV]  max_depth=1, max_features=1.0, min_samples_leaf=18, total=   0.1s
# [CV] max_depth=1, max_features=1.0, min_samples_leaf=18 ..............
# [CV]  max_depth=1, max_features=1.0, min_samples_leaf=18, total=   0.1s
# [CV] max_depth=1, max_features=1.0, min_samples_leaf=19 ..............
# [CV]  max_depth=1, max_features=1.0, min_samples_leaf=19, total=   0.1s
# [CV] max_depth=1, max_features=1.0, min_samples_leaf=19 ..............
# [CV]  max_depth=1, max_features=1.0, min_samples_leaf=19, total=   0.1s
# [CV] max_depth=1, max_features=1.0, min_samples_leaf=19 ..............
# [CV]  max_depth=1, max_features=1.0, min_samples_leaf=19, total=   0.1s
# [CV] max_depth=1, max_features=1.0, min_samples_leaf=19 ..............
# [CV]  max_depth=1, max_features=1.0, min_samples_leaf=19, total=   0.1s
# [CV] max_depth=1, max_features=1.0, min_samples_leaf=19 ..............
# [CV]  max_depth=1, max_features=1.0, min_samples_leaf=19, total=   0.1s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=1 ...............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=1, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=1 ...............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=1, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=1 ...............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=1, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=1 ...............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=1, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=1 ...............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=1, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=2 ...............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=2, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=2 ...............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=2, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=2 ...............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=2, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=2 ...............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=2, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=2 ...............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=2, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=3 ...............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=3, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=3 ...............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=3, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=3 ...............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=3, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=3 ...............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=3, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=3 ...............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=3, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=4 ...............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=4, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=4 ...............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=4, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=4 ...............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=4, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=4 ...............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=4, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=4 ...............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=4, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=5 ...............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=5, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=5 ...............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=5, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=5 ...............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=5, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=5 ...............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=5, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=5 ...............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=5, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=6 ...............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=6, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=6 ...............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=6, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=6 ...............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=6, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=6 ...............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=6, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=6 ...............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=6, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=7 ...............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=7, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=7 ...............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=7, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=7 ...............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=7, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=7 ...............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=7, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=7 ...............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=7, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=8 ...............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=8, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=8 ...............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=8, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=8 ...............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=8, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=8 ...............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=8, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=8 ...............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=8, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=9 ...............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=9, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=9 ...............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=9, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=9 ...............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=9, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=9 ...............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=9, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=9 ...............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=9, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=10 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=10, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=10 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=10, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=10 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=10, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=10 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=10, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=10 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=10, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=11 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=11, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=11 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=11, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=11 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=11, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=11 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=11, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=11 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=11, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=12 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=12, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=12 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=12, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=12 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=12, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=12 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=12, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=12 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=12, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=13 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=13, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=13 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=13, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=13 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=13, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=13 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=13, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=13 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=13, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=14 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=14, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=14 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=14, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=14 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=14, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=14 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=14, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=14 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=14, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=15 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=15, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=15 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=15, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=15 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=15, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=15 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=15, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=15 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=15, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=16 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=16, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=16 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=16, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=16 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=16, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=16 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=16, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=16 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=16, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=17 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=17, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=17 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=17, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=17 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=17, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=17 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=17, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=17 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=17, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=18 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=18, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=18 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=18, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=18 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=18, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=18 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=18, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=18 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=18, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=19 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=19, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=19 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=19, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=19 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=19, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=19 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=19, total=   0.0s
# [CV] max_depth=2, max_features=0.1, min_samples_leaf=19 ..............
# [CV]  max_depth=2, max_features=0.1, min_samples_leaf=19, total=   0.0s
# [CV] max_depth=2, max_features=0.2, min_samples_leaf=1 ...............
# [CV]  max_depth=2, max_features=0.2, min_samples_leaf=1, total=   0.0s
# [CV] max_depth=2, max_features=0.2, min_samples_leaf=1 ...............
# [CV]  max_depth=2, max_features=0.2, min_samples_leaf=1, total=   0.0s
# [CV] max_depth=2, max_features=0.2, min_samples_leaf=1 ...............
# [CV]  max_depth=2, max_features=0.2, min_samples_leaf=1, total=   0.0s
# [CV] max_depth=2, max_features=0.2, min_samples_leaf=1 ...............
# [CV]  max_depth=2, max_features=0.2, min_samples_leaf=1, total=   0.0s
# [CV] max_depth=2, max_features=0.2, min_samples_leaf=1 ...............
# [CV]  max_depth=2, max_features=0.2, min_samples_leaf=1, total=   0.0s
# [CV] max_depth=2, max_features=0.2, min_samples_leaf=2 ...............

# %%
print(f"The training accuracy is {round(train_acc*100,2)}%")
print(f"The test accuracy is {round(test_acc*100,2)}%")

# %% [markdown]
# Much better results! However, let's see how the model performs using the confusion matrix of the test set

# %%
figure, ax = plt.subplots(figsize=(7, 7))
disp = plot_confusion_matrix(my_tree_gs, X_test_mel, y_test,
                             display_labels = condition_label_encoder.classes_,
                             cmap=plt.cm.Blues,
                             normalize=None,
                             ax=ax)
disp.ax_.set_title("Decision Tree Confusion Matrix")
plt.show()

# %%
figure, ax = plt.subplots(figsize=(7, 7))
disp = plot_confusion_matrix(my_tree_gs, X_test_mel, y_test,
                             display_labels=condition_label_encoder.classes_,
                             cmap=plt.cm.Blues,
                             normalize='true',
                             ax=ax)
disp.ax_.set_title("Decision Tree Confusion Matrix")
plt.show()

# %% [markdown]
# As suspected, quite a bit of the classification seems to classify abnormal conditions and sounds as "normal" due to the sheer volume of that class, but interestingly, ~39% of the normal examples get misclassified as abnormalities.
#
# Let's see which feature the tree considers important:

# %%
plt.figure(figsize=(15, 5))
plt.plot(my_tree.feature_importances_)
plt.xlabel("Timestamp")
plt.ylabel("Feature Importance")
plt.title("Decision Tree Feature Importance")
plt.show()

# %%
print(classification_report(y_test, my_tree.predict(X_test_mel)))

# %% [markdown]
# ## Advanced Model - Random Forest
#
# ...

# %%
print(X_train_mel.shape, X_test_mel.shape)
print(y_train.shape, y_test.shape)

# %%
# %%time 

# Let's set some regularization otherwise we know the tree will overfit
my_gb = RandomForestClassifier(min_samples_leaf=2, 
                                     random_state=1, 
                                     n_estimators=1500).fit(X_train_mel, y_train)


train_acc = my_gb.score(X_train_mel, y_train)
test_acc = my_gb.score(X_test_mel, y_test)

# %%
print(f"The training accuracy is {round(train_acc*100,2)}%")
print(f"The test accuracy is {round(test_acc*100,2)}%")

# %% [markdown]
# Much better results! However, let's see how the model performs using the confusion matrix of the test set

# %%
figure, ax = plt.subplots(figsize=(7, 7))
disp = plot_confusion_matrix(my_gb, X_test_mel, y_test,
                             display_labels = condition_label_encoder.classes_,
                             cmap=plt.cm.Blues,
                             normalize=None,
                             ax=ax)
disp.ax_.set_title("Gradient Boosting Confusion Matrix")
plt.show()

# %%
figure, ax = plt.subplots(figsize=(7, 7))
disp = plot_confusion_matrix(my_gb, X_test_mel, y_test,
                             display_labels=condition_label_encoder.classes_,
                             cmap=plt.cm.Blues,
                             normalize='true',
                             ax=ax)
disp.ax_.set_title("Gradient Boosting Confusion Matrix")
plt.show()

# %%
print(classification_report(y_test, my_gb.predict(X_test_mel)))

# %% [markdown]
# ## Convolutional Neural Network

# %%
my_encoder = MelEncoder(flatten=False)

# %%
my_encoder.fit(train_dataset['signal'])

# %%
X_train_mel = my_encoder.transform(train_dataset['signal'])
#X_train_mel = np.expand_dims(X_train_mel, axis=-1)

# %%
X_train_min = X_train_mel.min()
print(X_train_min)
X_train_mel /= np.abs(X_train_min)
X_train_mel.shape

# %%
X_test_mel = my_encoder.transform(test_dataset['signal'])
#X_test_mel = np.expand_dims(X_test_mel, axis=-1)
X_test_mel /= np.abs(X_train_min)

# %%
X_test_mel.shape

# %%
condition_label_encoder = LabelEncoder()


y_train = condition_label_encoder.fit_transform(train_dataset['label'])[:X_train_mel.shape[0]]
y_test = condition_label_encoder.transform(test_dataset['label'])

print(X_train_mel.shape, X_test_mel.shape)
print(y_train.shape, y_test.shape)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Flatten, Conv2D, MaxPool2D, LSTM
from tensorflow.keras.optimizers import Adam

# %%
my_model = Sequential()

# %%
my_model.add(LSTM(25, activation="relu", input_shape = X_train_mel.shape[1:], return_sequences=True))
my_model.add(Dropout(0.2))
my_model.add(BatchNormalization())

my_model.add(LSTM(25, activation="relu", return_sequences=True))
my_model.add(Dropout(0.2))
my_model.add(BatchNormalization())

my_model.add(LSTM(25, activation="relu"))
my_model.add(Dropout(0.2))
my_model.add(BatchNormalization())

my_model.add(Dense(13, activation="relu"))
my_model.add(Dropout(0.2))
my_model.add(BatchNormalization())

my_model.add(Dense(3, activation="softmax"))

# %%
my_model.summary()

# %%
# Compile the model with the desired loss function, optimizer, and metric to optimize
my_model.compile(loss = 'sparse_categorical_crossentropy',
                  optimizer = 'Adam',
                  metrics = ['accuracy'])

# %%
my_model.fit(X_train_mel, y_train,
              batch_size = 12,
              epochs = 10,
              verbose = 1,
              validation_data=(X_test_mel, y_test))

# %%
my_model.add(Conv2D(13, activation="relu", kernel_size=(3,3), input_shape = X_train_mel.shape[1:]))
my_model.add(Dropout(0.2))
my_model.add(BatchNormalization())
my_model.add(MaxPool2D())

my_model.add(Conv2D(12, activation="relu", kernel_size=(3,3)))
my_model.add(Dropout(0.2))
my_model.add(BatchNormalization())
my_model.add(MaxPool2D())

my_model.add(Conv2D(12, activation="relu", kernel_size=(3,3)))
my_model.add(Dropout(0.2))
my_model.add(BatchNormalization())
my_model.add(MaxPool2D())

my_model.add(Flatten())

my_model.add(Dense(13, activation="relu"))
my_model.add(Dropout(0.2))
my_model.add(BatchNormalization())

my_model.add(Dense(3, activation="softmax"))

# %%
my_model.summary()

# %%
# Compile the model with the desired loss function, optimizer, and metric to optimize
my_model.compile(loss = 'sparse_categorical_crossentropy',
                  optimizer = 'Adam',
                  metrics = ['accuracy'])

# %%
my_model.fit(X_train_mel, y_train,
              batch_size = 12,
              epochs = 10,
              verbose = 1,
              validation_data=(X_test_mel, y_test))

# %%
# Evaluate the model's performance on the test data
score = my_model.evaluate(X_test_mel, y_test, verbose=1)

print('Test loss:', score[0])
print('Test accuracy:', score[1])

# %%
y_test

# %%
my_model.predict(X_test_mel)
